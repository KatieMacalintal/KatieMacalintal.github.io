# %% [raw]
# ---
# title: Implementing Linear Regression
# author: Katie Macalintal
# date: '2023-03-15'
# image: "gradient_descent.png"
# description: "Implement least-squares linear regression, including the useful LASSO regularization for overparameterized problems"
# format: html
# ---

# %% [markdown]
# ## DEMO

# %%
import numpy as np
from matplotlib import pyplot as plt

def pad(X):
    return np.append(X, np.ones((X.shape[0], 1)), 1)

def LR_data(n_train = 100, n_val = 100, p_features = 1, noise = .1, w = None):
    if w is None: 
        w = np.random.rand(p_features + 1) + .2
    
    X_train = np.random.rand(n_train, p_features)
    y_train = pad(X_train)@w + noise*np.random.randn(n_train)

    X_val = np.random.rand(n_val, p_features)
    y_val = pad(X_val)@w + noise*np.random.randn(n_val)
    
    return X_train, y_train, X_val, y_val

# %%
n_train = 100
n_val = 100
p_features = 1
noise = 0.2

# create some data
X_train, y_train, X_val, y_val = LR_data(n_train, n_val, p_features, noise)

# plot it
fig, axarr = plt.subplots(1, 2, sharex = True, sharey = True)
axarr[0].scatter(X_train, y_train)
axarr[1].scatter(X_val, y_val)
labs = axarr[0].set(title = "Training", xlabel = "x", ylabel = "y")
labs = axarr[1].set(title = "Validation", xlabel = "x")
plt.tight_layout()

# %%
from linear_regression import LinearRegression

LR = LinearRegression()
LR.fit_analytic(X_train, y_train) # I used the analytical formula as my default fit method

print(f"Training score = {LR.score(pad(X_train), y_train).round(4)}")
print(f"Validation score = {LR.score(pad(X_val), y_val).round(4)}")
# Out:
# Training score = 0.6713
# Validation score = 0.6264

# %%
LR.w
# Out:
# array([1.02174917, 0.75508997])

# %%
LR2 = LinearRegression()

LR2.fit_gradient(X_train, y_train, alpha = 0.01, max_iter = 1e2)

# %%
LR2.w
# Out:
# array([1.02111976, 0.75541124])

# %%
plt.plot(LR2.score_history)
labels = plt.gca().set(xlabel = "Iteration", ylabel = "Score")

# %% [markdown]
# ## Experiments

# %%
n_train = 1000
n_val = 100
p_features = 1
noise = 0.2

training_scores = []
validation_scores = []

while (p_features < n_train):
    # create some data
    X_train, y_train, X_val, y_val = LR_data(n_train, n_val, p_features, noise)
    LR = LinearRegression()
    LR.fit_analytic(X_train, y_train)
    training_scores.append(LR.score(pad(X_train), y_train))
    validation_scores.append(LR.score(pad(X_val), y_val))
    p_features += 1
    
plt.plot(training_scores, label="training score")
plt.plot(training_scores, label="validation score")

legend = plt.legend() 
labels = plt.gca().set(xlabel = "Number of Features", ylabel = "Score")
